# %% [markdown]
# # Importando base de dados

# %%
import pandas as pd

# %%
pd.read_csv('tips.csv')
# Out:
#      total_bill   tip dessert   day    time  size
# 0         16.99  1.01      No   Sun  Dinner     2
# 1         10.34  1.66      No   Sun  Dinner     3
# 2         21.01  3.50      No   Sun  Dinner     3
# 3         23.68  3.31      No   Sun  Dinner     2
# 4         24.59  3.61      No   Sun  Dinner     4
# ..          ...   ...     ...   ...     ...   ...
# 239       29.03  5.92      No   Sat  Dinner     3
# 240       27.18  2.00     Yes   Sat  Dinner     2
# 241       22.67  2.00     Yes   Sat  Dinner     2
# 242       17.82  1.75      No   Sat  Dinner     2
# 243       18.78  3.00      No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
dados = pd.read_csv('tips.csv')
dados
# Out:
#      total_bill   tip dessert   day    time  size
# 0         16.99  1.01      No   Sun  Dinner     2
# 1         10.34  1.66      No   Sun  Dinner     3
# 2         21.01  3.50      No   Sun  Dinner     3
# 3         23.68  3.31      No   Sun  Dinner     2
# 4         24.59  3.61      No   Sun  Dinner     4
# ..          ...   ...     ...   ...     ...   ...
# 239       29.03  5.92      No   Sat  Dinner     3
# 240       27.18  2.00     Yes   Sat  Dinner     2
# 241       22.67  2.00     Yes   Sat  Dinner     2
# 242       17.82  1.75      No   Sat  Dinner     2
# 243       18.78  3.00      No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
dados.head(10)
# Out:
#    total_bill   tip dessert  day    time  size
# 0       16.99  1.01      No  Sun  Dinner     2
# 1       10.34  1.66      No  Sun  Dinner     3
# 2       21.01  3.50      No  Sun  Dinner     3
# 3       23.68  3.31      No  Sun  Dinner     2
# 4       24.59  3.61      No  Sun  Dinner     4
# 5       25.29  4.71      No  Sun  Dinner     4
# 6        8.77  2.00      No  Sun  Dinner     2
# 7       26.88  3.12      No  Sun  Dinner     4
# 8       15.04  1.96      No  Sun  Dinner     2
# 9       14.78  3.23      No  Sun  Dinner     2

# %% [markdown]
# ## Tradução

# %%
dados.columns
# Out:
# Index(['total_bill', 'tip', 'dessert', 'day', 'time', 'size'], dtype='object')

# %%
renomear = {
    'total_bill' : 'valor_da_conta',
    'tip' : 'gorjeta',
    'dessert' : 'sobremesa',
    'day' : 'dia_da_semana',
    'time' : 'hora_do_dia',
    'size' : 'total_de_pessoas'
}

# %%
gorjetas = dados.rename(columns = renomear)
gorjetas
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0             16.99     1.01        No           Sun      Dinner
# 1             10.34     1.66        No           Sun      Dinner
# 2             21.01     3.50        No           Sun      Dinner
# 3             23.68     3.31        No           Sun      Dinner
# 4             24.59     3.61        No           Sun      Dinner
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92        No           Sat      Dinner
# 240           27.18     2.00       Yes           Sat      Dinner
# 241           22.67     2.00       Yes           Sat      Dinner
# 242           17.82     1.75        No           Sat      Dinner
# 243           18.78     3.00        No          Thur      Dinner
#
#      total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# 239                 3
# 240                 2
# 241                 2
# 242                 2
# 243                 2
#
# [244 rows x 6 columns]

# %%
gorjetas.sobremesa.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sim_nao = {
    'No' : 'Não',
    'Yes' : 'Sim'
}

# %%
gorjetas.sobremesa.map(sim_nao)
# Out:
# 0      Não
# 1      Não
# 2      Não
# 3      Não
# 4      Não
#       ...
# 239    Não
# 240    Sim
# 241    Sim
# 242    Não
# 243    Não
# Name: sobremesa, Length: 244, dtype: object

# %%
gorjetas.head(1)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01        No           Sun      Dinner
#
#    total_de_pessoas
# 0                 2

# %%
gorjetas.sobremesa = gorjetas.sobremesa.map(sim_nao)

# %%
gorjetas
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0             16.99     1.01       Não           Sun      Dinner
# 1             10.34     1.66       Não           Sun      Dinner
# 2             21.01     3.50       Não           Sun      Dinner
# 3             23.68     3.31       Não           Sun      Dinner
# 4             24.59     3.61       Não           Sun      Dinner
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92       Não           Sat      Dinner
# 240           27.18     2.00       Sim           Sat      Dinner
# 241           22.67     2.00       Sim           Sat      Dinner
# 242           17.82     1.75       Não           Sat      Dinner
# 243           18.78     3.00       Não          Thur      Dinner
#
#      total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# 239                 3
# 240                 2
# 241                 2
# 242                 2
# 243                 2
#
# [244 rows x 6 columns]

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
dias = {
    'Sun' : 'Domingo',
    'Sat' : 'Sábado',
    'Thur' : 'Quinta',
    'Fri' : 'Sexta'
}

# %%
gorjetas.dia_da_semana = gorjetas.dia_da_semana.map(dias)

# %%
gorjetas
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0             16.99     1.01       Não       Domingo      Dinner
# 1             10.34     1.66       Não       Domingo      Dinner
# 2             21.01     3.50       Não       Domingo      Dinner
# 3             23.68     3.31       Não       Domingo      Dinner
# 4             24.59     3.61       Não       Domingo      Dinner
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92       Não        Sábado      Dinner
# 240           27.18     2.00       Sim        Sábado      Dinner
# 241           22.67     2.00       Sim        Sábado      Dinner
# 242           17.82     1.75       Não        Sábado      Dinner
# 243           18.78     3.00       Não        Quinta      Dinner
#
#      total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# 239                 3
# 240                 2
# 241                 2
# 242                 2
# 243                 2
#
# [244 rows x 6 columns]

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
hora = {
    'Dinner' : 'Jantar',
    'Lunch' : 'Almoço'
}

# %%
gorjetas.hora_do_dia = gorjetas.hora_do_dia.map(hora)

# %%
gorjetas
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0             16.99     1.01       Não       Domingo      Jantar
# 1             10.34     1.66       Não       Domingo      Jantar
# 2             21.01     3.50       Não       Domingo      Jantar
# 3             23.68     3.31       Não       Domingo      Jantar
# 4             24.59     3.61       Não       Domingo      Jantar
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92       Não        Sábado      Jantar
# 240           27.18     2.00       Sim        Sábado      Jantar
# 241           22.67     2.00       Sim        Sábado      Jantar
# 242           17.82     1.75       Não        Sábado      Jantar
# 243           18.78     3.00       Não        Quinta      Jantar
#
#      total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# 239                 3
# 240                 2
# 241                 2
# 242                 2
# 243                 2
#
# [244 rows x 6 columns]

# %% [markdown]
# ## Importando o Seaborn

# %%
# !pip install seaborn==0.9.0
# Out:
# Requirement already satisfied: seaborn==0.9.0 in c:\users\andri\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: scipy>=0.14.0 in c:\users\andri\anaconda3\lib\site-packages (from seaborn==0.9.0) (1.9.1)
# Requirement already satisfied: pandas>=0.15.2 in c:\users\andri\anaconda3\lib\site-packages (from seaborn==0.9.0) (1.4.4)
# Requirement already satisfied: numpy>=1.9.3 in c:\users\andri\anaconda3\lib\site-packages (from seaborn==0.9.0) (1.21.5)
# Requirement already satisfied: matplotlib>=1.4.3 in c:\users\andri\anaconda3\lib\site-packages (from seaborn==0.9.0) (3.5.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\andri\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\andri\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\andri\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\andri\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\andri\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\andri\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\andri\anaconda3\lib\site-packages (from matplotlib>=1.4.3->seaborn==0.9.0) (9.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\andri\anaconda3\lib\site-packages (from pandas>=0.15.2->seaborn==0.9.0) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\andri\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.3->seaborn==0.9.0) (1.16.0)

# %%
import seaborn as sns

# %% [markdown]
# ## Análise I - Valor da conta e gorjeta

# %%
valor_gorjeta = sns.scatterplot(x= 'valor_da_conta', y='gorjeta',data=gorjetas)

# %% [markdown]
# ## visualmente o valor da gorjeta aumenta conforme o valor da conta

# %%
print('A base de dados possui {} registros\n'.format(gorjetas.shape[0]))
print('registros não nulos')
gorjetas.count()
# Out:
# A base de dados possui 244 registros
#
# registros não nulos
# valor_da_conta      244
# gorjeta             244
# sobremesa           244
# dia_da_semana       244
# hora_do_dia         244
# total_de_pessoas    244
# dtype: int64

# %% [markdown]
# ## Criando o campo porcentagem

# %%
campo_porcentagem = (gorjetas.gorjeta / gorjetas.valor_da_conta) * 100
gorjetas['porcentagem'] = campo_porcentagem.round(2)
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         5.94
# 1                 3        16.05
# 2                 3        16.66
# 3                 2        13.98
# 4                 4        14.68

# %%
porcentagem_conta = sns.scatterplot(x='valor_da_conta', y= 'porcentagem', data = gorjetas)

# %% [markdown]
# ## Visualmente o valor da conta, não é proporcional o valor da gorjeta

# %%
porcentagem_conta_linha = sns.relplot(x='valor_da_conta', y='porcentagem',kind = 'line', data= gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y= 'porcentagem', data= gorjetas)

# %% [markdown]
# ## Análise II - sobremesa

# %%
gorjetas
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0             16.99     1.01       Não       Domingo      Jantar
# 1             10.34     1.66       Não       Domingo      Jantar
# 2             21.01     3.50       Não       Domingo      Jantar
# 3             23.68     3.31       Não       Domingo      Jantar
# 4             24.59     3.61       Não       Domingo      Jantar
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92       Não        Sábado      Jantar
# 240           27.18     2.00       Sim        Sábado      Jantar
# 241           22.67     2.00       Sim        Sábado      Jantar
# 242           17.82     1.75       Não        Sábado      Jantar
# 243           18.78     3.00       Não        Quinta      Jantar
#
#      total_de_pessoas  porcentagem
# 0                   2         5.94
# 1                   3        16.05
# 2                   3        16.66
# 3                   2        13.98
# 4                   4        14.68
# ..                ...          ...
# 239                 3        20.39
# 240                 2         7.36
# 241                 2         8.82
# 242                 2         9.82
# 243                 2        15.97
#
# [244 rows x 7 columns]

# %%
gorjetas[gorjetas.sobremesa == 'Sim']
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 56            38.01     3.00       Sim        Sábado      Jantar
# 58            11.24     1.76       Sim        Sábado      Jantar
# 60            20.29     3.21       Sim        Sábado      Jantar
# 61            13.81     2.00       Sim        Sábado      Jantar
# 62            11.02     1.98       Sim        Sábado      Jantar
# ..              ...      ...       ...           ...         ...
# 234           15.53     3.00       Sim        Sábado      Jantar
# 236           12.60     1.00       Sim        Sábado      Jantar
# 237           32.83     1.17       Sim        Sábado      Jantar
# 240           27.18     2.00       Sim        Sábado      Jantar
# 241           22.67     2.00       Sim        Sábado      Jantar
#
#      total_de_pessoas  porcentagem
# 56                  4         7.89
# 58                  2        15.66
# 60                  2        15.82
# 61                  2        14.48
# 62                  2        17.97
# ..                ...          ...
# 234                 2        19.32
# 236                 2         7.94
# 237                 2         3.56
# 240                 2         7.36
# 241                 2         8.82
#
# [93 rows x 7 columns]

# %%
gorjetas[gorjetas.sobremesa == 'Sim'].describe()
# Out:
#        valor_da_conta    gorjeta  total_de_pessoas  porcentagem
# count       93.000000  93.000000         93.000000    93.000000
# mean        20.756344   3.008710          2.408602    16.319140
# std          9.832154   1.401468          0.810751     8.511748
# min          3.070000   1.000000          1.000000     3.560000
# 25%         13.420000   2.000000          2.000000    10.680000
# 50%         17.920000   3.000000          2.000000    15.380000
# 75%         26.860000   3.680000          3.000000    19.510000
# max         50.810000  10.000000          5.000000    71.030000

# %%
gorjetas[gorjetas.sobremesa == 'Não'].describe()
# Out:
#        valor_da_conta     gorjeta  total_de_pessoas  porcentagem
# count      151.000000  151.000000        151.000000   151.000000
# mean        19.188278    2.991854          2.668874    15.932318
# std          8.255582    1.377190          1.017984     3.990701
# min          7.250000    1.000000          1.000000     5.680000
# 25%         13.325000    2.000000          2.000000    13.690000
# 50%         17.590000    2.740000          2.000000    15.560000
# 75%         22.755000    3.505000          3.000000    18.500000
# max         48.330000    9.000000          6.000000    29.200000

# %%
sns.catplot(x='sobremesa', y='gorjeta', data = gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa' ,data= gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', col = 'sobremesa' ,data= gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='gorjeta', col='sobremesa', hue='sobremesa', data= gorjetas)

# %% [markdown]
# ## Visualmente existe uma diferença no valor da gorjeta daqueles que pediram sobremesa e daqueles que não pediram sobremesa

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', col='sobremesa', hue='sobremesa', kind= 'line' ,data= gorjetas)

# %%
from scipy.stats import ranksums

# %%
sobremesa = gorjetas.query("sobremesa == 'Sim'").porcentagem
sobremesa
# Out:
# 56      7.89
# 58     15.66
# 60     15.82
# 61     14.48
# 62     17.97
#        ...
# 234    19.32
# 236     7.94
# 237     3.56
# 240     7.36
# 241     8.82
# Name: porcentagem, Length: 93, dtype: float64

# %%
sem_sobremesa = gorjetas.query("sobremesa == 'Não'").porcentagem
sem_sobremesa
# Out:
# 0       5.94
# 1      16.05
# 2      16.66
# 3      13.98
# 4      14.68
#        ...
# 235    12.41
# 238    13.03
# 239    20.39
# 242     9.82
# 243    15.97
# Name: porcentagem, Length: 151, dtype: float64

# %%
r = ranksums(sobremesa, sem_sobremesa)

# %%
print('o valor do pvalue é {}'.format(r.pvalue))
# Out:
# o valor do pvalue é 0.558850059321255

# %% [markdown]
# ## A distribuição da taxa da gorjeta é a mesma nos dois grupos

# %%
gorjetas
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0             16.99     1.01       Não       Domingo      Jantar
# 1             10.34     1.66       Não       Domingo      Jantar
# 2             21.01     3.50       Não       Domingo      Jantar
# 3             23.68     3.31       Não       Domingo      Jantar
# 4             24.59     3.61       Não       Domingo      Jantar
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92       Não        Sábado      Jantar
# 240           27.18     2.00       Sim        Sábado      Jantar
# 241           22.67     2.00       Sim        Sábado      Jantar
# 242           17.82     1.75       Não        Sábado      Jantar
# 243           18.78     3.00       Não        Quinta      Jantar
#
#      total_de_pessoas  porcentagem
# 0                   2         5.94
# 1                   3        16.05
# 2                   3        16.66
# 3                   2        13.98
# 4                   4        14.68
# ..                ...          ...
# 239                 3        20.39
# 240                 2         7.36
# 241                 2         8.82
# 242                 2         9.82
# 243                 2        15.97
#
# [244 rows x 7 columns]

# %% [markdown]
# # Análise III - dia da semana

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Domingo', 'Sábado', 'Quinta', 'Sexta'], dtype=object)

# %%
sns.catplot(x='dia_da_semana', y='valor_da_conta', data = gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana', data= gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', data= gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana', col = 'dia_da_semana' ,data= gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', col = 'dia_da_semana' ,data= gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', col = 'dia_da_semana' ,data= gorjetas)

# %%
media_geral_gorjeta= gorjetas.gorjeta.mean()
media_geral_gorjeta
# Out:
# 2.9982786885245902

# %%
print(f'A média geral das gorjetas é de {media_geral_gorjeta}')
# Out:
# A média geral das gorjetas é de 2.9982786885245902

# %%
gorjetas.groupby(['dia_da_semana']).mean()
# Out:
#                valor_da_conta   gorjeta  total_de_pessoas  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132          2.842105    16.689605
# Quinta              17.682742  2.771452          2.451613    16.126452
# Sexta               17.151579  2.734737          2.105263    16.991579
# Sábado              20.441379  2.993103          2.517241    15.314598

# %%
gorjetas.groupby(['dia_da_semana']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
# Out:
#                valor_da_conta   gorjeta  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132    16.689605
# Quinta              17.682742  2.771452    16.126452
# Sexta               17.151579  2.734737    16.991579
# Sábado              20.441379  2.993103    15.314598

# %%
print('Frequência dos dias')
gorjetas.dia_da_semana.value_counts()
# Out:
# Frequência dos dias
# Sábado     87
# Domingo    76
# Quinta     62
# Sexta      19
# Name: dia_da_semana, dtype: int64

# %% [markdown]
# ## Teste de hipótese

# %%
domingo = gorjetas.query("dia_da_semana == 'Domingo'").valor_da_conta

# %%
sabado = gorjetas.query("dia_da_semana == 'Sábado'").valor_da_conta

# %%
r2 = ranksums(domingo,sabado)
print(f'o valor do pvalue é {r2.pvalue}')
# Out:
# o valor do pvalue é 0.3576728477868443

# %% [markdown]
# ## A distribuição do valor da conta é igual no sábado e no domingo

# %% [markdown]
# # Análise IV - Hora do dia

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Jantar', 'Almoço'], dtype=object)

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta', data = gorjetas)

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta', kind = 'swarm', data = gorjetas)

# %%
sns.violinplot(x='hora_do_dia', y='valor_da_conta', data= gorjetas)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
sns.boxplot(x='hora_do_dia', y='valor_da_conta', data = gorjetas)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
almoco = gorjetas.query("hora_do_dia == 'Almoço'").valor_da_conta

# %%
sns.distplot(almoco)
# Out:
# <AxesSubplot:xlabel='valor_da_conta'>

# %%
sns.distplot(almoco, kde = False)
# Out:
# <AxesSubplot:xlabel='valor_da_conta'>

# %%
gorjetas.groupby(['hora_do_dia']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
# Out:
#              valor_da_conta   gorjeta  porcentagem
# hora_do_dia
# Almoço            17.168676  2.728088    16.411765
# Jantar            20.797159  3.102670    15.951477
